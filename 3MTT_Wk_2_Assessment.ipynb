# %% [markdown]
# ##Importing library

# %%
##importing library
import pandas as pd

# %% [markdown]
# ##importing dataset

# %%
user = pd.read_excel("/3MTT Assessment Week 2.xlsx")

# %% [markdown]
# ##printing the data set

# %%
#viewing the data set
print(user)
# Out:
#         Products  Orders  Pieces
# 0      Meat pies      10   25pcs
# 1         Samosa      20  100pcs
# 2       Cupcakes      15  100pcs
# 3         Donuts       5   10pcs
# 4        Cookies       5   50pcs
# 5  Spring rolls       10   40pcs
# 6     Cake slice      15   40pcs
# 7      Cake loaf      20   50pcs
# 8         Ginger      19   50pcs
# 9     Milk shake      20   60pcs

# %% [markdown]
# ##printing the first 5 rows of the dataset

# %%
#viewing the head
user.head()
# Out:
#     Products  Orders  Pieces
# 0  Meat pies      10   25pcs
# 1     Samosa      20  100pcs
# 2   Cupcakes      15  100pcs
# 3     Donuts       5   10pcs
# 4    Cookies       5   50pcs

# %% [markdown]
# ##printing the last 5 rows of the data set

# %%
#viewing the tail
user.tail()
# Out:
#         Products  Orders Pieces
# 5  Spring rolls       10  40pcs
# 6     Cake slice      15  40pcs
# 7      Cake loaf      20  50pcs
# 8         Ginger      19  50pcs
# 9     Milk shake      20  60pcs

# %% [markdown]
# ##showing file information

# %%
##viewing dataset information
user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Products  10 non-null     object
#  1   Orders    10 non-null     int64
#  2   Pieces    10 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 368.0+ bytes

# %% [markdown]
# ##displaying the describtion of the data set

# %%
#displaying dataset discription
user.describe()
# Out:
#         Orders
# count  10.0000
# mean   13.9000
# std     6.0452
# min     5.0000
# 25%    10.0000
# 50%    15.0000
# 75%    19.7500
# max    20.0000
